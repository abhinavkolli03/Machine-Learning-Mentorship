# %%
import math

first_split = []
feature_values = []
for i in range(22): 
  feature_values.append([])

def getData():
  for line in open("agaricus-lepiota.data", 'r'):
    parts = line.split(",")
    first_split.append(parts[0])
    for i in range(22):
      feature_values[i].append(parts[i + 1])

def find_probability(current_list, value):
  summation = 0
  for i in current_list:
    if i == value:
      summation += 1
  return summation/len(current_list)

def find_conditional_value(feature_values, first_split, element):
  pore = []
  for i in range(len(feature_values)):
    if feature_values[i] == value:
      pore.append(Y[x])
  poccur = sum('p' in s for s in pore)
  eoccur = sum('e' in s for s in pore)
  return eoccur/len(pore)

def find_unique_probability(index, elements):
  probabilities = []
  for x in elements:
    unique_prob = find_probability(feature_values[index], x)
    probabilities.append(unique_prob)
  return probabilities

def find_elements(current_list): 
  elements = []
  for i in current_list:
    if i not in elements:
      elements.append(i)
  return elements

def calculate_entropy(chance):
  total = -sum([math.log(chance), math.log(1-chance)])
  return total

def main():
  getData()
  first_split_probability_p = find_probability(first_split, "p")
  first_split_probability_e = find_probability(first_split, "e")
  entropy_total = calculate_entropy(first_split_probability_p) + calculate_entropy(first_split_probability_e)
  print("Total Entropy: " + str(entropy_total))
  elements = find_elements(feature_values[0])
  print(elements)
  probX = []  
  
main()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-31-4de71c86b46e> in <module>()
#      57   probX = []
#      58
# ---> 59 main()
#
# <ipython-input-31-4de71c86b46e> in main()
#      49 def main():
#      50   getData()
# ---> 51   first_split_probability_p = find_probability(first_split, "p")
#      52   first_split_probability_e = find_probability(first_split, "e")
#      53   entropy_total = calculate_entropy(first_split_probability_p) + calculate_entropy(first_split_probability_e)
#
# <ipython-input-31-4de71c86b46e> in find_probability(current_list, value)
#      18     if i == value:
#      19       summation += 1
# ---> 20   return summation/len(current_list)
#      21
#      22 def find_conditional_value(feature_values, first_split, element):
#
# ZeroDivisionError: division by zero
